# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import chart_studio.plotly as py
import plotly.graph_objects as go

# %%
cf.go_offline(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import csv
lst = []
with open('1.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')

    for row in spamreader:

         print(', '.join(row))
# Out:
# main_category_name,ranking,title,ori_price,dis_price,discount_percent,
# Electronics,-5,None,None,None,0,
# Sports/Motors,-5,None,None,None,0,
# Books/Music,-5,None,None,None,0,
# Stationery/Hobbies,-5,None,None,None,0,
# Baby/Maternity,-5,None,None,None,0,
# Home/Health,-5,None,None,None,0,
# Furniture/Bedding,-5,None,None,None,0,
# Food,-5,None,None,None,0,
# Beauty,-5,None,None,None,0,
# Apparel,-5,None,None,None,0,
# Acc./Shoes,-5,None,None,None,0,
# ALL,-5,None,None,None,0,
# main_category_name,ranking,title,ori_price,dis_price,discount_percent,
# Stationery/Hobbies,-5,None,None,None,0,
# Sports/Motors,-5,None,None,None,0,
# Home/Health,-5,None,None,None,0,
# Food,-5,None,None,None,0,
# Electronics,-5,None,None,None,0,
# Stationery/Hobbies,-4,None,None,None,0,
# Stationery/Hobbies,-3,None,None,None,0,
# Books/Music,-5,None,None,None,0,
# Sports/Motors,-4,None,None,None,0,
# Sports/Motors,-3,None,None,None,0,
# Home/Health,-4,None,None,None,0,
# Home/Health,-3,None,None,None,0,
# ...

# %%
df1 = pd.read_csv('1.csv',encoding='ISO-8859-1'  )

# %%
df2 = df1.loc[df1['title'] != 'None'].iloc[:,:6]

# %%
idx = []
for index,i in enumerate(df2['dis_price']):
    if '%' not in i:
        idx.append(index)

# %%
df3 = df2.iloc[idx,:]

# %%
df2.iloc[idx,:]
# Out:
#        main_category_name  ranking  \
# 12     main_category_name  ranking
# 52     Stationery/Hobbies        1
# 68                   Food        1
# 70            Electronics        1
# 86            Books/Music        1
# ...                   ...      ...
# 24040          Acc./Shoes       96
# 24041          Acc./Shoes       97
# 24042          Acc./Shoes       98
# 24043          Acc./Shoes       99
# 24044          Acc./Shoes      100
#
#                                                    title  ori_price  \
# 12                                                 title  ori_price
# 52          Auntmimipet pet stroller frame guard cushion       None
# 68     KANU MINI Ice Blend 100 sticks Coffee Mix+Para...       None
# 70          BT21 BABY AUTOMOTIVE CAR MONITOR MINI FIGURE       None
# 86              WJSN 2022 CONCERT WONDERLAND - PHOTO SET       None
# ...                                                  ...        ...
# ...

# %%
df4 = df3.drop_duplicates().reset_index()

# %%
df4.loc[0,'ori_price']
# Out:
# 'ori_price'

# %%
idx = []
for i in range(df4.shape[0]):
    if (df4.loc[i,'ori_price'] != 'None') and (df4.loc[i,'dis_price'] != None) :
        idx.append(i)

# %%
df4
# Out:
#       index  main_category_name  ranking  \
# 0        12  main_category_name  ranking
# 1        52  Stationery/Hobbies        1
# 2        68                Food        1
# 3        70         Electronics        1
# 4        86         Books/Music        1
# ...     ...                 ...      ...
# 5986  23846                Food       92
# 5987  23847                Food       93
# 5988  23898             Apparel       84
# 5989  23899             Apparel       85
# 5990  24013              Beauty       95
#
#                                                   title  ori_price  dis_price  \
# 0                                                 title  ori_price  dis_price
# 1          Auntmimipet pet stroller frame guard cushion       None       None
# 2     KANU MINI Ice Blend 100 sticks Coffee Mix+Para...       None       None
# 3          BT21 BABY AUTOMOTIVE CAR MONITOR MINI FIGURE       None       None
# ...
